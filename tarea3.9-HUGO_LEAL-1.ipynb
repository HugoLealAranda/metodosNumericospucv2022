# %%
print("tarea 3.8")
from time import time
import matplotlib
# Out:
# tarea 3.8

# %%
tiempo_inicial=time()
n = 1000
s = 0 
for i in range(n):
    for j in range(n):
        if i < j:
            s = s + i + j
tiempo_final=time()
tiempo_total=tiempo_final-tiempo_inicial
print("el tiempo que toma en ejecutar este codigo es de:", tiempo_total, "segundos", "y su eficiencia es de O(n**2)")
# el comando for in es un ciclo  que se considera un ciclo anidado en otro por eso N es de grado 2
# Out:
# el tiempo que toma en ejecutar este codigo es de: 0.06985902786254883 segundos y su eficiencia es de O(n**2)

# %%
tiempo_inicial=time()
n = 1000
s = 0
for i in range(n):
    for j in range(i):
        s = s + i + j
tiempo_final=time()
tiempo_total=tiempo_final-tiempo_inicial
print("el tiempo que toma en ejecutar este codigo es de:", tiempo_total, "segundos", "y su eficiencia es de O(n**2)")

# el comando for in es un ciclo  que se considera un ciclo anidado en otro por eso N es de grado 2
# Out:
# el tiempo que toma en ejecutar este codigo es de: 0.05413508415222168 segundos y su eficiencia es de O(n**2)

# %%
tiempo_inicial=time()
n = 1000
s = 0
for i in range(n):
    s = s + i + sum(range(n))
tiempo_final=time()
tiempo_total=tiempo_final-tiempo_inicial
print("el tiempo que toma en ejecutar este codigo es de:", tiempo_total, "segundos", "y su eficiencia es de O(n**2)")
# el comando sum() es ciclo de suma, asi que se considera un ciclo anidado en otro por eso N es de grado 2
# Out:
# el tiempo que toma en ejecutar este codigo es de: -0.010438203811645508 segundos y su eficiencia es de O(n**2)

# %%
from time import time  #se importa tiempo desde su modulo
import matplotlib.pyplot as plt #se importa el modulo matplotlib.pyplot
tiempo_inicial=time()  #se toma el tiempo en este punto
R=list(range(1000,10000000000,100000))  #creo una lista de "N's" para poder recorrer despues
listadePasos=[] #se crea una lista vacia de pasos para ir agregando cada vez que termine el ciclo while
for n in R:     #for in para crear un dato "pasos" cada vez que se recorra while en un N 
    small = 0           
    p = 146
    attempt = n//2
    not_found = True
    s = 0
    listadeN=[]
    while not_found:
        s = s + 1
        if attempt > p:
            n = attempt
        elif attempt < p:
            small = attempt
        else:
            #print('Encontré', attempt, 'luego de', s, 'pasos')
            listadePasos.append(s)   #aqui agrego un dato pasos a la lista cada vez que se completa un ciclo while en un N
            break
        attempt = (n + small)//2
tiempo_final=time() #toma de tiempo final 
tiempo_total=tiempo_final-tiempo_inicial  #calculo delta tiempo
print("el tiempo que toma en ejecutar este codigo es de:", tiempo_total, "segundos", "y la funcion relacionada a su eficiencia es logaritmica O(log n), como se aprecia en la gráfica")
plt.plot(R,listadePasos)  #aca se grafica la lista N creada previamente, y la lista pasos ( para cada N hay un numero finito de pasos)
plt.xlabel("numero de N")
plt.ylabel("numero de pasos por cada N")
plt.title(" N / pasos ")
# Out:
# el tiempo que toma en ejecutar este codigo es de: 0.3806939125061035 segundos y la funcion relacionada a su eficiencia es logaritmica O(log n), como se aprecia en la gráfica
# Text(0.5, 1.0, ' N / pasos ')

# %% [markdown]
# # Calificación: 7.0
